# %% [markdown]
# <a href="https://colab.research.google.com/github/nahir97/Fooocus/blob/main/Forge_attempt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/nahir97/stable-diffusion-webui-forge.git
# %cd /content/stable-diffusion-webui-forge

# !sudo apt-get update && sudo apt-get install -y aria2

# Existing downloads (keep previous commands)
# !aria2c -c -x8 -s8 "https://huggingface.co/Zveir/MyLoras/resolve/main/flux16s.gguf" -d "./models/Stable-diffusion" -o "flux16s.gguf"
# !aria2c -c -x8 -s8 "https://huggingface.co/Zveir/MyLoras/resolve/main/clip_l.safetensors" -d "./models/text_encoder" -o "clip_l.safetensors"
# !aria2c -c -x8 -s8 "https://huggingface.co/Zveir/MyLoras/resolve/main/t5-v1_1-xxl-encoder-Q4_K_S.gguf" -d "./models/text_encoder" -o "t5-v1_1-xxl-encoder-Q4_K_S.gguf"
# !aria2c -c -x8 -s8 "https://huggingface.co/Zveir/MyLoras/resolve/main/ae.safetensors" -d "./models/VAE" -o "ae.safetensors"

# !python webui.py
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 13.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# ...
# /content
# Cloning into 'stable-diffusion-webui-forge'...
# remote: Enumerating objects: 41805, done.
# remote: Counting objects: 100% (9884/9884), done.
# remote: Compressing objects: 100% (532/532), done.
# remote: Total 41805 (delta 9392), reused 9352 (delta 9352), pack-reused 31921 (from 3)
# Receiving objects: 100% (41805/41805), 46.35 MiB | 17.83 MiB/s, done.
# Resolving deltas: 100% (29050/29050), done.
# /content/stable-diffusion-webui-forge
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# ...
